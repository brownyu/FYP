# %%
import pandas as pd 
data = pd.read_csv("..\Datasets\Experimental results for virtual daily living test.csv",header = 1)
data
# Out:
#    Group  G Code Subject  Gender  Age  Edu Level  GDSSF-K  MMSE-DS  K-IADL   \
# 0     HC       0      P1       1   71         14        2       26       10
# 1     HC       0      P2       1   68          9        2       30       10
# 2     HC       0      P3       0   78         15        4       28       10
# 3     HC       0      P4       1   67         16        6       30       10
# 4     HC       0      P5       1   67         15        3       28       10
# 5     HC       0      P6       1   70          6        4       29       10
# 6     HC       0      P7       1   68          6        1       28       10
# 7     HC       0      P8       1   71          6        3       28       10
# 8     HC       0      P9       1   69          9        0       25       10
# 9     HC       0     P10       1   72          9        4       28       10
# 10    HC       0     P11       0   79          8        3       27       10
# ...
